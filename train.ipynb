# %% [markdown]
# # Faster RCNN Inception Resnet V2 training

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle
! cp PATH/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d omkarnadkarni/lisa-traffic-sign
# Out:
# Downloading lisa-traffic-sign.zip to /content
# 100% 7.96G/7.99G [00:53<00:00, 239MB/s]
# 100% 7.99G/7.99G [00:53<00:00, 160MB/s]

# %%
! unzip lisa-traffic-sign.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: negatives/negativePics/nosign09515.png
#   inflating: negatives/negativePics/nosign09516.png
#   inflating: negatives/negativePics/nosign09517.png
#   inflating: negatives/negativePics/nosign09518.png
#   inflating: negatives/negativePics/nosign09519.png
#   inflating: negatives/negativePics/nosign09520.png
#   inflating: negatives/negativePics/nosign09521.png
#   inflating: negatives/negativePics/nosign09522.png
#   inflating: negatives/negativePics/nosign09523.png
#   inflating: negatives/negativePics/nosign09524.png
#   inflating: negatives/negativePics/nosign09525.png
#   inflating: negatives/negativePics/nosign09526.png
#   inflating: negatives/negativePics/nosign09527.png
#   inflating: negatives/negativePics/nosign09528.png
#   inflating: negatives/negativePics/nosign09529.png
#   inflating: negatives/negativePics/nosign09530.png
#   inflating: negatives/negativePics/nosign09531.png
#   inflating: negatives/negativePics/nosign09532.png
#   inflating: negatives/negativePics/nosign09533.png
#   inflating: negatives/negativePics/nosign09534.png
#   inflating: negatives/negativePics/nosign09535.png
#   inflating: negatives/negativePics/nosign09536.png
#   inflating: negatives/negativePics/nosign09537.png
#   inflating: negatives/negativePics/nosign09538.png
#   inflating: negatives/negativePics/nosign09539.png
#   inflating: negatives/negativePics/nosign09540.png
#   inflating: negatives/negativePics/nosign09541.png
#   inflating: negatives/negativePics/nosign09542.png
#   inflating: negatives/negativePics/nosign09543.png
#   inflating: negatives/negativePics/nosign09544.png
#   inflating: negatives/negativePics/nosign09545.png
#   inflating: negatives/negativePics/nosign09546.png
#   inflating: negatives/negativePics/nosign09547.png
#   inflating: negatives/negativePics/nosign09548.png
#   inflating: negatives/negativePics/nosign09549.png
#   inflating: negatives/negativePics/nosign09550.png
#   inflating: negatives/negativePics/nosign09551.png
#   inflating: negatives/negativePics/nosign09552.png
#   inflating: negatives/negativePics/nosign09553.png
#   inflating: negatives/negativePics/nosign09554.png
#   inflating: negatives/negativePics/nosign09555.png
#   inflating: negatives/negativePics/nosign09556.png
#   inflating: negatives/negativePics/nosign09557.png
#   inflating: negatives/negativePics/nosign09558.png
#   inflating: negatives/negativePics/nosign09559.png
#   inflating: negatives/negativePics/nosign09560.png
#   inflating: negatives/negativePics/nosign09561.png
#   inflating: negatives/negativePics/nosign09562.png
#   inflating: negatives/negativePics/nosign09563.png
#   inflating: negatives/negativePics/nosign09564.png
#   inflating: negatives/negativePics/nosign09565.png
#   inflating: negatives/negativePics/nosign09566.png
#   inflating: negatives/negativePics/nosign09567.png
#   inflating: negatives/negativePics/nosign09568.png
#   inflating: negatives/negativePics/nosign09569.png
#   inflating: negatives/negativePics/nosign09570.png
#   inflating: negatives/negativePics/nosign09571.png
#   inflating: negatives/negativePics/nosign09572.png
#   inflating: negatives/negativePics/nosign09573.png
#   inflating: negatives/negativePics/nosign09574.png
#   inflating: negatives/negativePics/nosign09575.png
#   inflating: negatives/negativePics/nosign09576.png
#   inflating: negatives/negativePics/nosign09577.png
#   inflating: negatives/negativePics/nosign09578.png
#   inflating: negatives/negativePics/nosign09579.png
#   inflating: negatives/negativePics/nosign09580.png
#   inflating: negatives/negativePics/nosign09581.png
#   inflating: negatives/negativePics/nosign09582.png
#   inflating: negatives/negativePics/nosign09583.png
#   inflating: negatives/negativePics/nosign09584.png
#   inflating: negatives/negativePics/nosign09585.png
#   inflating: negatives/negativePics/nosign09586.png
#   inflating: negatives/negativePics/nosign09587.png
#   inflating: negatives/negativePics/nosign09588.png
#   inflating: negatives/negativePics/nosign09589.png
#   inflating: negatives/negativePics/nosign09590.png
#   inflating: negatives/negativePics/nosign09591.png
#   inflating: negatives/negativePics/nosign09592.png
#   inflating: negatives/negativePics/nosign09593.png
#   inflating: negatives/negativePics/nosign09594.png
#   inflating: negatives/negativePics/nosign09595.png
#   inflating: negatives/negativePics/nosign09596.png
#   inflating: negatives/negativePics/nosign09597.png
#   inflating: negatives/negativePics/nosign09598.png
#   inflating: negatives/negativePics/nosign09599.png
#   inflating: negatives/negativePics/nosign09600.png
#   inflating: negatives/negativePics/nosign09601.png
#   inflating: negatives/negativePics/nosign09602.png
#   inflating: negatives/negativePics/nosign09603.png
#   inflating: negatives/negativePics/nosign09604.png
#   inflating: negatives/negativePics/nosign09605.png
#   inflating: negatives/negativePics/nosign09606.png
#   inflating: negatives/negativePics/nosign09607.png
#   inflating: negatives/negativePics/nosign09608.png
#   inflating: negatives/negativePics/nosign09609.png
#   inflating: negatives/negativePics/nosign09610.png
#   inflating: negatives/negativePics/nosign09611.png
#   inflating: negatives/negativePics/nosign09612.png
#   inflating: negatives/negativePics/nosign09613.png
#   inflating: negatives/negativePics/nosign09614.png
#   inflating: negatives/negativePics/nosign09615.png
#   inflating: negatives/negativePics/nosign09616.png
#   inflating: negatives/negativePics/nosign09617.png
#   inflating: negatives/negativePics/nosign09618.png
#   inflating: negatives/negativePics/nosign09619.png
#   inflating: negatives/negativePics/nosign09620.png
#   inflating: negatives/negativePics/nosign09621.png
#   inflating: negatives/negativePics/nosign09622.png
#   inflating: negatives/negativePics/nosign09623.png
#   inflating: negatives/negativePics/nosign09624.png
#   inflating: negatives/negativePics/nosign09625.png
#   inflating: negatives/negativePics/nosign09626.png
#   inflating: negatives/negativePics/nosign09627.png
#   inflating: negatives/negativePics/nosign09628.png
#   inflating: negatives/negativePics/nosign09629.png
#   inflating: negatives/negativePics/nosign09630.png
#   inflating: negatives/negativePics/nosign09631.png
#   inflating: negatives/negativePics/nosign09632.png
#   inflating: negatives/negativePics/nosign09633.png
#   inflating: negatives/negativePics/nosign09634.png
#   inflating: negatives/negativePics/nosign09635.png
#   inflating: negatives/negativePics/nosign09636.png
#   inflating: negatives/negativePics/nosign09637.png
#   inflating: negatives/negativePics/nosign09638.png
#   inflating: negatives/negativePics/nosign09639.png
#   inflating: negatives/negativePics/nosign09640.png
#   inflating: negatives/negativePics/nosign09641.png
#   inflating: negatives/negativePics/nosign09642.png
#   inflating: negatives/negativePics/nosign09643.png
#   inflating: negatives/negativePics/nosign09644.png
#   inflating: negatives/negativePics/nosign09645.png
#   inflating: negatives/negativePics/nosign09646.png
#   inflating: negatives/negativePics/nosign09647.png
#   inflating: negatives/negativePics/nosign09648.png
#   inflating: negatives/negativePics/nosign09649.png
#   inflating: negatives/negativePics/nosign09650.png
#   inflating: negatives/negativePics/nosign09651.png
#   inflating: negatives/negativePics/nosign09652.png
#   inflating: negatives/negativePics/nosign09653.png
#   inflating: negatives/negativePics/nosign09654.png
#   inflating: negatives/negativePics/nosign09655.png
#   inflating: negatives/negativePics/nosign09656.png
#   inflating: negatives/negativePics/nosign09657.png
#   inflating: negatives/negativePics/nosign09658.png
#   inflating: negatives/negativePics/nosign09659.png
#   inflating: negatives/negativePics/nosign09660.png
#   inflating: negatives/negativePics/nosign09661.png
#   inflating: negatives/negativePics/nosign09662.png
#   inflating: negatives/negativePics/nosign09663.png
#   inflating: negatives/negativePics/nosign09664.png
#   inflating: negatives/negativePics/nosign09665.png
#   inflating: negatives/negativePics/nosign09666.png
#   inflating: negatives/negativePics/nosign09667.png
#   inflating: negatives/negativePics/nosign09668.png
#   inflating: negatives/negativePics/nosign09669.png
#   inflating: negatives/negativePics/nosign09670.png
#   inflating: negatives/negativePics/nosign09671.png
#   inflating: negatives/negativePics/nosign09672.png
#   inflating: negatives/negativePics/nosign09673.png
#   inflating: negatives/negativePics/nosign09674.png
#   inflating: negatives/negativePics/nosign09675.png
#   inflating: negatives/negativePics/nosign09676.png
#   inflating: negatives/negativePics/nosign09677.png
#   inflating: negatives/negativePics/nosign09678.png
#   inflating: negatives/negativePics/nosign09679.png
#   inflating: negatives/negativePics/nosign09680.png
#   inflating: negatives/negativePics/nosign09681.png
#   inflating: negatives/negativePics/nosign09682.png
#   inflating: negatives/negativePics/nosign09683.png
#   inflating: negatives/negativePics/nosign09684.png
#   inflating: negatives/negativePics/nosign09685.png
#   inflating: negatives/negativePics/nosign09686.png
#   inflating: negatives/negativePics/nosign09687.png
#   inflating: negatives/negativePics/nosign09688.png
#   inflating: negatives/negativePics/nosign09689.png
#   inflating: negatives/negativePics/nosign09690.png
#   inflating: negatives/negativePics/nosign09691.png
#   inflating: negatives/negativePics/nosign09692.png
#   inflating: negatives/negativePics/nosign09693.png
#   inflating: negatives/negativePics/nosign09694.png
#   inflating: negatives/negativePics/nosign09695.png
#   inflating: negatives/negativePics/nosign09696.png
#   inflating: negatives/negativePics/nosign09697.png
#   inflating: negatives/negativePics/nosign09698.png
#   inflating: negatives/negativePics/nosign09699.png
#   inflating: negatives/negativePics/nosign09700.png
#   inflating: negatives/negativePics/nosign09701.png
#   inflating: negatives/negativePics/nosign09702.png
#   inflating: negatives/negativePics/nosign09703.png
#   inflating: negatives/negativePics/nosign09704.png
#   inflating: negatives/negativePics/nosign09705.png
#   inflating: negatives/negativePics/nosign09706.png
#   inflating: negatives/negativePics/nosign09707.png
#   inflating: negatives/negativePics/nosign09708.png
#   inflating: negatives/negativePics/nosign09709.png
#   inflating: negatives/negativePics/nosign09710.png
#   inflating: negatives/negativePics/nosign09711.png
#   inflating: negatives/negativePics/nosign09712.png
#   inflating: negatives/negativePics/nosign09713.png
#   inflating: negatives/negativePics/nosign09714.png
#   inflating: negatives/negativePics/nosign09715.png
#   inflating: negatives/negativePics/nosign09716.png
#   inflating: negatives/negativePics/nosign09717.png
#   inflating: negatives/negativePics/nosign09718.png
#   inflating: negatives/negativePics/nosign09719.png
#   inflating: negatives/negativePics/nosign09720.png
#   inflating: negatives/negativePics/nosign09721.png
#   inflating: negatives/negativePics/nosign09722.png
#   inflating: negatives/negativePics/nosign09723.png
#   inflating: negatives/negativePics/nosign09724.png
#   inflating: negatives/negativePics/nosign09725.png
#   inflating: negatives/negativePics/nosign09726.png
#   inflating: negatives/negativePics/nosign09727.png
#   inflating: negatives/negativePics/nosign09728.png
#   inflating: negatives/negativePics/nosign09729.png
#   inflating: negatives/negativePics/nosign09730.png
#   inflating: negatives/negativePics/nosign09731.png
#   inflating: negatives/negativePics/nosign09732.png
#   inflating: negatives/negativePics/nosign09733.png
#   inflating: negatives/negativePics/nosign09734.png
#   inflating: negatives/negativePics/nosign09735.png
#   inflating: negatives/negativePics/nosign09736.png
#   inflating: negatives/negativePics/nosign09737.png
#   inflating: negatives/negativePics/nosign09738.png
#   inflating: negatives/negativePics/nosign09739.png
#   inflating: negatives/negativePics/nosign09740.png
#   inflating: negatives/negativePics/nosign09741.png
#   inflating: negatives/negativePics/nosign09742.png
#   inflating: negatives/negativePics/nosign09743.png
#   inflating: negatives/negativePics/nosign09744.png
#   inflating: negatives/negativePics/nosign09745.png
#   inflating: negatives/negativePics/nosign09746.png
#   inflating: negatives/negativePics/nosign09747.png
#   inflating: negatives/negativePics/nosign09748.png
#   inflating: negatives/negativePics/nosign09749.png
#   inflating: negatives/negativePics/nosign09750.png
#   inflating: negatives/negativePics/nosign09751.png
#   inflating: negatives/negativePics/nosign09752.png
#   inflating: negatives/negativePics/nosign09753.png
#   inflating: negatives/negativePics/nosign09754.png
#   inflating: negatives/negativePics/nosign09755.png
#   inflating: negatives/negativePics/nosign09756.png
#   inflating: negatives/negativePics/nosign09757.png
#   inflating: negatives/negativePics/nosign09758.png
#   inflating: negatives/negativePics/nosign09759.png
#   inflating: negatives/negativePics/nosign09760.png
#   inflating: negatives/negativePics/nosign09761.png
#   inflating: negatives/negativePics/nosign09762.png
#   inflating: negatives/negativePics/nosign09763.png
#   inflating: negatives/negativePics/nosign09764.png
#   inflating: negatives/negativePics/nosign09765.png
#   inflating: negatives/negativePics/nosign09766.png
#   inflating: negatives/negativePics/nosign09767.png
#   inflating: negatives/negativePics/nosign09768.png
#   inflating: negatives/negativePics/nosign09769.png
#   inflating: negatives/negativePics/nosign09770.png
#   inflating: negatives/negativePics/nosign09771.png
#   inflating: negatives/negativePics/nosign09772.png
#   inflating: negatives/negativePics/nosign09773.png
#   inflating: negatives/negativePics/nosign09774.png
#   inflating: negatives/negativePics/nosign09775.png
#   inflating: negatives/negativePics/nosign09776.png
#   inflating: negatives/negativePics/nosign09777.png
#   inflating: negatives/negativePics/nosign09778.png
#   inflating: negatives/negativePics/nosign09779.png
#   inflating: negatives/negativePics/nosign09780.png
#   inflating: negatives/negativePics/nosign09781.png
#   inflating: negatives/negativePics/nosign09782.png
#   inflating: negatives/negativePics/nosign09783.png
#   inflating: negatives/negativePics/nosign09784.png
#   inflating: negatives/negativePics/nosign09785.png
#   inflating: negatives/negativePics/nosign09786.png
#   inflating: negatives/negativePics/nosign09787.png
#   inflating: negatives/negativePics/nosign09788.png
#   inflating: negatives/negativePics/nosign09789.png
#   inflating: negatives/negativePics/nosign09790.png
#   inflating: negatives/negativePics/nosign09791.png
#   inflating: negatives/negativePics/nosign09792.png
#   inflating: negatives/negativePics/nosign09793.png
#   inflating: negatives/negativePics/nosign09794.png
#   inflating: negatives/negativePics/nosign09795.png
#   inflating: negatives/negativePics/nosign09796.png
#   inflating: negatives/negativePics/nosign09797.png
#   inflating: negatives/negativePics/nosign09798.png
#   inflating: negatives/negativePics/nosign09799.png
#   inflating: negatives/negativePics/nosign09800.png
#   inflating: negatives/negativePics/nosign09801.png
#   inflating: negatives/negativePics/nosign09802.png
#   inflating: negatives/negativePics/nosign09803.png
#   inflating: negatives/negativePics/nosign09804.png
#   inflating: negatives/negativePics/nosign09805.png
#   inflating: negatives/negativePics/nosign09806.png
#   inflating: negatives/negativePics/nosign09807.png
#   inflating: negatives/negativePics/nosign09808.png
#   inflating: negatives/negativePics/nosign09809.png
#   inflating: negatives/negativePics/nosign09810.png
#   inflating: negatives/negativePics/nosign09811.png
#   inflating: negatives/negativePics/nosign09812.png
#   inflating: negatives/negativePics/nosign09813.png
#   inflating: negatives/negativePics/nosign09814.png
#   inflating: negatives/negativePics/nosign09815.png
#   inflating: negatives/negativePics/nosign09816.png
#   inflating: negatives/negativePics/nosign09817.png
#   inflating: negatives/negativePics/nosign09818.png
#   inflating: negatives/negativePics/nosign09819.png
#   inflating: negatives/negativePics/nosign09820.png
#   inflating: negatives/negativePics/nosign09821.png
#   inflating: negatives/negativePics/nosign09822.png
#   inflating: negatives/negativePics/nosign09823.png
#   inflating: negatives/negativePics/nosign09824.png
#   inflating: negatives/negativePics/nosign09825.png
#   inflating: negatives/negativePics/nosign09826.png
#   inflating: negatives/negativePics/nosign09827.png
#   inflating: negatives/negativePics/nosign09828.png
#   inflating: negatives/negativePics/nosign09829.png
#   inflating: negatives/negativePics/nosign09830.png
#   inflating: negatives/negativePics/nosign09831.png
#   inflating: negatives/negativePics/nosign09832.png
#   inflating: negatives/negativePics/nosign09833.png
#   inflating: negatives/negativePics/nosign09834.png
#   inflating: negatives/negativePics/nosign09835.png
#   inflating: negatives/negativePics/nosign09836.png
#   inflating: negatives/negativePics/nosign09837.png
#   inflating: negatives/negativePics/nosign09838.png
#   inflating: negatives/negativePics/nosign09839.png
#   inflating: negatives/negativePics/nosign09840.png
#   inflating: negatives/negativePics/nosign09841.png
#   inflating: negatives/negativePics/nosign09842.png
#   inflating: negatives/negativePics/nosign09843.png
#   inflating: negatives/negativePics/nosign09844.png
#   inflating: negatives/negativePics/nosign09845.png
#   inflating: negatives/negativePics/nosign09846.png
#   inflating: negatives/negativePics/nosign09847.png
#   inflating: negatives/negativePics/nosign09848.png
#   inflating: negatives/negativePics/nosign09849.png
#   inflating: negatives/negativePics/nosign09850.png
#   inflating: negatives/negativePics/nosign09851.png
#   inflating: negatives/negativePics/nosign09852.png
#   inflating: negatives/negativePics/nosign09853.png
#   inflating: negatives/negativePics/nosign09854.png
#   inflating: negatives/negativePics/nosign09855.png
#   inflating: negatives/negativePics/nosign09856.png
#   inflating: negatives/negativePics/nosign09857.png
#   inflating: negatives/negativePics/nosign09858.png
#   inflating: negatives/negativePics/nosign09859.png
#   inflating: negatives/negativePics/nosign09860.png
#   inflating: negatives/negativePics/nosign09861.png
#   inflating: negatives/negativePics/nosign09862.png
#   inflating: negatives/negativePics/nosign09863.png
#   inflating: negatives/negativePics/nosign09864.png
#   inflating: negatives/negativePics/nosign09865.png
#   inflating: negatives/negativePics/nosign09866.png
#   inflating: negatives/negativePics/nosign09867.png
#   inflating: negatives/negativePics/nosign09868.png
#   inflating: negatives/negativePics/nosign09869.png
#   inflating: negatives/negativePics/nosign09870.png
#   inflating: negatives/negativePics/nosign09871.png
#   inflating: negatives/negativePics/nosign09872.png
#   inflating: negatives/negativePics/nosign09873.png
#   inflating: negatives/negativePics/nosign09874.png
#   inflating: negatives/negativePics/nosign09875.png
#   inflating: negatives/negativePics/nosign09876.png
#   inflating: negatives/negativePics/nosign09877.png
#   inflating: negatives/negativePics/nosign09878.png
#   inflating: negatives/negativePics/nosign09879.png
#   inflating: negatives/negativePics/nosign09880.png
#   inflating: negatives/negativePics/nosign09881.png
#   inflating: negatives/negativePics/nosign09882.png
#   inflating: negatives/negativePics/nosign09883.png
#   inflating: negatives/negativePics/nosign09884.png
#   inflating: negatives/negativePics/nosign09885.png
#   inflating: negatives/negativePics/nosign09886.png
#   inflating: negatives/negativePics/nosign09887.png
#   inflating: negatives/negativePics/nosign09888.png
#   inflating: negatives/negativePics/nosign09889.png
#   inflating: negatives/negativePics/nosign09890.png
#   inflating: negatives/negativePics/nosign09891.png
#   inflating: negatives/negativePics/nosign09892.png
#   inflating: negatives/negativePics/nosign09893.png
#   inflating: negatives/negativePics/nosign09894.png
#   inflating: negatives/negativePics/nosign09895.png
#   inflating: negatives/negativePics/nosign09896.png
#   inflating: negatives/negativePics/nosign09897.png
#   inflating: negatives/negativePics/nosign09898.png
#   inflating: negatives/negativePics/nosign09899.png
#   inflating: negatives/negativePics/nosign09900.png
#   inflating: negatives/negativePics/nosign09901.png
#   inflating: negatives/negativePics/nosign09902.png
#   inflating: negatives/negativePics/nosign09903.png
#   inflating: negatives/negativePics/nosign09904.png
#   inflating: negatives/negativePics/nosign09905.png
#   inflating: negatives/negativePics/nosign09906.png
#   inflating: negatives/negativePics/nosign09907.png
#   inflating: negatives/negativePics/nosign09908.png
#   inflating: negatives/negativePics/nosign09909.png
#   inflating: negatives/negativePics/nosign09910.png
#   inflating: negatives/negativePics/nosign09911.png
#   inflating: negatives/negativePics/nosign09912.png
#   inflating: negatives/negativePics/nosign09913.png
#   inflating: negatives/negativePics/nosign09914.png
#   inflating: negatives/negativePics/nosign09915.png
#   inflating: negatives/negativePics/nosign09916.png
#   inflating: negatives/negativePics/nosign09917.png
#   inflating: negatives/negativePics/nosign09918.png
#   inflating: negatives/negativePics/nosign09919.png
#   inflating: negatives/negativePics/nosign09920.png
#   inflating: negatives/negativePics/nosign09921.png
#   inflating: negatives/negativePics/nosign09922.png
#   inflating: negatives/negativePics/nosign09923.png
#   inflating: negatives/negativePics/nosign09924.png
#   inflating: negatives/negativePics/nosign09925.png
#   inflating: negatives/negativePics/nosign09926.png
#   inflating: negatives/negativePics/nosign09927.png
#   inflating: negatives/negativePics/nosign09928.png
#   inflating: negatives/negativePics/nosign09929.png
#   inflating: negatives/negativePics/nosign09930.png
#   inflating: negatives/negativePics/nosign09931.png
#   inflating: negatives/negativePics/nosign09932.png
#   inflating: negatives/negativePics/nosign09933.png
#   inflating: negatives/negativePics/nosign09934.png
#   inflating: negatives/negativePics/nosign09935.png
#   inflating: negatives/negativePics/nosign09936.png
#   inflating: negatives/negativePics/nosign09937.png
#   inflating: negatives/negativePics/nosign09938.png
#   inflating: negatives/negativePics/nosign09939.png
#   inflating: negatives/negativePics/nosign09940.png
#   inflating: negatives/negativePics/nosign09941.png
#   inflating: negatives/negativePics/nosign09942.png
#   inflating: negatives/negativePics/nosign09943.png
#   inflating: negatives/negativePics/nosign09944.png
#   inflating: negatives/negativePics/nosign09945.png
#   inflating: negatives/negativePics/nosign09946.png
#   inflating: negatives/negativePics/nosign09947.png
#   inflating: negatives/negativePics/nosign09948.png
#   inflating: negatives/negativePics/nosign09949.png
#   inflating: negatives/negativePics/nosign09950.png
#   inflating: negatives/negativePics/nosign09951.png
#   inflating: negatives/negativePics/nosign09952.png
#   inflating: negatives/negativePics/nosign09953.png
#   inflating: negatives/negativePics/nosign09954.png
#   inflating: negatives/negativePics/nosign09955.png
#   inflating: negatives/negativePics/nosign09956.png
#   inflating: negatives/negativePics/nosign09957.png
#   inflating: negatives/negativePics/nosign09958.png
#   inflating: negatives/negativePics/nosign09959.png
#   inflating: negatives/negativePics/nosign09960.png
#   inflating: negatives/negativePics/nosign09961.png
#   inflating: negatives/negativePics/nosign09962.png
#   inflating: negatives/negativePics/nosign09963.png
#   inflating: negatives/negativePics/nosign09964.png
#   inflating: negatives/negativePics/nosign09965.png
#   inflating: negatives/negativePics/nosign09966.png
#   inflating: negatives/negativePics/nosign09967.png
#   inflating: negatives/negativePics/nosign09968.png
#   inflating: negatives/negativePics/nosign09969.png
#   inflating: negatives/negativePics/nosign09970.png
#   inflating: negatives/negativePics/nosign09971.png
#   inflating: negatives/negativePics/nosign09972.png
#   inflating: negatives/negativePics/nosign09973.png
#   inflating: negatives/negativePics/nosign09974.png
#   inflating: negatives/negativePics/nosign09975.png
#   inflating: negatives/negativePics/nosign09976.png
#   inflating: negatives/negativePics/nosign09977.png
#   inflating: negatives/negativePics/nosign09978.png
#   inflating: negatives/negativePics/nosign09979.png
#   inflating: negatives/negativePics/nosign09980.png
#   inflating: negatives/negativePics/nosign09981.png
#   inflating: negatives/negativePics/nosign09982.png
#   inflating: negatives/negativePics/nosign09983.png
#   inflating: negatives/negativePics/nosign09984.png
#   inflating: negatives/negativePics/nosign09985.png
#   inflating: negatives/negativePics/nosign09986.png
#   inflating: negatives/negativePics/nosign09987.png
#   inflating: negatives/negativePics/nosign09988.png
#   inflating: negatives/negativePics/nosign09989.png
#   inflating: negatives/negativePics/nosign09990.png
#   inflating: negatives/negativePics/nosign09991.png
#   inflating: negatives/negativePics/nosign09992.png
#   inflating: negatives/negativePics/nosign09993.png
#   inflating: negatives/negativePics/nosign09994.png
#   inflating: negatives/negativePics/nosign09995.png
#   inflating: negatives/negativePics/nosign09996.png
#   inflating: negatives/negativePics/nosign09997.png
#   inflating: negatives/negativePics/nosign09998.png
#   inflating: negatives/negativePics/nosign09999.png
#   inflating: negatives/negativePics/nosign10000.png
#   inflating: negatives/negativePics/nosign10001.png
#   inflating: negatives/negativePics/nosign10002.png
#   inflating: negatives/negativePics/nosign10003.png
#   inflating: negatives/negativePics/nosign10004.png
#   inflating: negatives/negativePics/nosign10005.png
#   inflating: negatives/negativePics/nosign10006.png
#   inflating: negatives/negativePics/nosign10007.png
#   inflating: negatives/negativePics/nosign10008.png
#   inflating: negatives/negativePics/nosign10009.png
#   inflating: negatives/negativePics/nosign10010.png
#   inflating: negatives/negativePics/nosign10011.png
#   inflating: negatives/negativePics/nosign10012.png
#   inflating: negatives/negativePics/nosign10013.png
#   inflating: negatives/negativePics/nosign10014.png
#   inflating: negatives/negativePics/nosign10015.png
#   inflating: negatives/negativePics/nosign10016.png
#   inflating: negatives/negativePics/nosign10017.png
#   inflating: negatives/negativePics/nosign10018.png
#   inflating: negatives/negativePics/nosign10019.png
#   inflating: negatives/negativePics/nosign10020.png
#   inflating: negatives/negativePics/nosign10021.png
#   inflating: negatives/negativePics/nosign10022.png
#   inflating: negatives/negativePics/nosign10023.png
#   inflating: negatives/negativePics/nosign10024.png
#   inflating: negatives/negativePics/nosign10025.png
#   inflating: negatives/negativePics/nosign10026.png
#   inflating: negatives/negativePics/nosign10027.png
#   inflating: negatives/negativePics/nosign10028.png
#   inflating: negatives/negativePics/nosign10029.png
#   inflating: negatives/negativePics/nosign10030.png
#   inflating: negatives/negativePics/nosign10031.png
#   inflating: negatives/negativePics/nosign10032.png
#   inflating: negatives/negativePics/nosign10033.png
#   inflating: negatives/negativePics/nosign10034.png
#   inflating: negatives/negativePics/nosign10035.png
#   inflating: negatives/negativePics/nosign10036.png
#   inflating: negatives/negativePics/nosign10037.png
#   inflating: negatives/negativePics/nosign10038.png
#   inflating: negatives/negativePics/nosign10039.png
#   inflating: negatives/negativePics/nosign10040.png
#   inflating: negatives/negativePics/nosign10041.png
#   inflating: negatives/negativePics/nosign10042.png
#   inflating: negatives/negativePics/nosign10043.png
#   inflating: negatives/negativePics/nosign10044.png
#   inflating: negatives/negativePics/nosign10045.png
#   inflating: negatives/negativePics/nosign10046.png
#   inflating: negatives/negativePics/nosign10047.png
#   inflating: negatives/negativePics/nosign10048.png
#   inflating: negatives/negativePics/nosign10049.png
#   inflating: negatives/negativePics/nosign10050.png
#   inflating: negatives/negativePics/nosign10051.png
#   inflating: negatives/negativePics/nosign10052.png
#   inflating: negatives/negativePics/nosign10053.png
#   inflating: negatives/negativePics/nosign10054.png
#   inflating: negatives/negativePics/nosign10055.png
#   inflating: negatives/negativePics/nosign10056.png
#   inflating: negatives/negativePics/nosign10057.png
#   inflating: negatives/negativePics/nosign10058.png
#   inflating: negatives/negativePics/nosign10059.png
#   inflating: negatives/negativePics/nosign10060.png
#   inflating: negatives/negativePics/nosign10061.png
#   inflating: negatives/negativePics/nosign10062.png
#   inflating: negatives/negativePics/nosign10063.png
#   inflating: negatives/negativePics/nosign10064.png
#   inflating: negatives/negativePics/nosign10065.png
#   inflating: negatives/negativePics/nosign10066.png
#   inflating: negatives/negativePics/nosign10067.png
#   inflating: negatives/negativePics/nosign10068.png
#   inflating: negatives/negativePics/nosign10069.png
#   inflating: negatives/negativePics/nosign10070.png
#   inflating: negatives/negativePics/nosign10071.png
#   inflating: negatives/negativePics/nosign10072.png
#   inflating: negatives/negativePics/nosign10073.png
#   inflating: negatives/negativePics/nosign10074.png
#   inflating: negatives/negativePics/nosign10075.png
#   inflating: negatives/negativePics/nosign10076.png
#   inflating: negatives/negativePics/nosign10077.png
#   inflating: negatives/negativePics/nosign10078.png
#   inflating: negatives/negativePics/nosign10079.png
#   inflating: negatives/negativePics/nosign10080.png
#   inflating: negatives/negativePics/nosign10081.png
#   inflating: negatives/negativePics/nosign10082.png
#   inflating: negatives/negativePics/nosign10083.png
#   inflating: negatives/negativePics/nosign10084.png
#   inflating: negatives/negativePics/nosign10085.png
#   inflating: negatives/negativePics/nosign10086.png
#   inflating: negatives/negativePics/nosign10087.png
#   inflating: negatives/negativePics/nosign10088.png
#   inflating: negatives/negativePics/nosign10089.png
#   inflating: negatives/negativePics/nosign10090.png
#   inflating: negatives/negativePics/nosign10091.png
#   inflating: negatives/negativePics/nosign10092.png
#   inflating: negatives/negativePics/nosign10093.png
#   inflating: negatives/negativePics/nosign10094.png
#   inflating: negatives/negativePics/nosign10095.png
#   inflating: negatives/negativePics/nosign10096.png
#   inflating: negatives/negativePics/nosign10097.png
#   inflating: negatives/negativePics/nosign10098.png
#   inflating: negatives/negativePics/nosign10099.png
#   inflating: negatives/negativePics/nosign10100.png
#   inflating: negatives/negativePics/nosign10101.png
#   inflating: negatives/negativePics/nosign10102.png
#   inflating: negatives/negativePics/nosign10103.png
#   inflating: negatives/negativePics/nosign10104.png
#   inflating: negatives/negativePics/nosign10105.png
#   inflating: negatives/negativePics/nosign10106.png
#   inflating: negatives/negativePics/nosign10107.png
#   inflating: negatives/negativePics/nosign10108.png
#   inflating: negatives/negativePics/nosign10109.png
#   inflating: negatives/negativePics/nosign10110.png
#   inflating: negatives/negativePics/nosign10111.png
#   inflating: negatives/negativePics/nosign10112.png
#   inflating: negatives/negativePics/nosign10113.png
#   inflating: negatives/negativePics/nosign10114.png
#   inflating: negatives/negativePics/nosign10115.png
#   inflating: negatives/negativePics/nosign10116.png
#   inflating: negatives/negativePics/nosign10117.png
#   inflating: negatives/negativePics/nosign10118.png
#   inflating: negatives/negativePics/nosign10119.png
#   inflating: negatives/negativePics/nosign10120.png
#   inflating: negatives/negativePics/nosign10121.png
#   inflating: negatives/negativePics/nosign10122.png
#   inflating: negatives/negativePics/nosign10123.png
#   inflating: negatives/negativePics/nosign10124.png
#   inflating: negatives/negativePics/nosign10125.png
#   inflating: negatives/negativePics/nosign10126.png
#   inflating: negatives/negativePics/nosign10127.png
#   inflating: negatives/negativePics/nosign10128.png
#   inflating: negatives/negativePics/nosign10129.png
#   inflating: negatives/negativePics/nosign10130.png
#   inflating: negatives/negativePics/nosign10131.png
#   inflating: negatives/negativePics/nosign10132.png
#   inflating: negatives/negativePics/nosign10133.png
#   inflating: negatives/negativePics/nosign10134.png
#   inflating: negatives/negativePics/nosign10135.png
#   inflating: negatives/negativePics/nosign10136.png
#   inflating: negatives/negativePics/nosign10137.png
#   inflating: negatives/negativePics/nosign10138.png
#   inflating: negatives/negativePics/nosign10139.png
#   inflating: negatives/negativePics/nosign10140.png
#   inflating: negatives/negativePics/nosign10141.png
#   inflating: negatives/negativePics/nosign10142.png
#   inflating: negatives/negativePics/nosign10143.png
#   inflating: negatives/negativePics/nosign10144.png
#   inflating: negatives/negativePics/nosign10145.png
#   inflating: negatives/negativePics/nosign10146.png
#   inflating: negatives/negativePics/nosign10147.png
#   inflating: negatives/negativePics/nosign10148.png
#   inflating: negatives/negativePics/nosign10149.png
#   inflating: negatives/negativePics/nosign10150.png
#   inflating: negatives/negativePics/nosign10151.png
#   inflating: negatives/negativePics/nosign10152.png
#   inflating: negatives/negativePics/nosign10153.png
#   inflating: negatives/negativePics/nosign10154.png
#   inflating: negatives/negativePics/nosign10155.png
#   inflating: negatives/negativePics/nosign10156.png
#   inflating: negatives/negativePics/nosign10157.png
#   inflating: negatives/negativePics/nosign10158.png
#   inflating: negatives/negativePics/nosign10159.png
#   inflating: negatives/negativePics/nosign10160.png
#   inflating: negatives/negativePics/nosign10161.png
#   inflating: negatives/negativePics/nosign10162.png
#   inflating: negatives/negativePics/nosign10163.png
#   inflating: negatives/negativePics/nosign10164.png
#   inflating: negatives/negativePics/nosign10165.png
#   inflating: negatives/negativePics/nosign10166.png
#   inflating: negatives/negativePics/nosign10167.png
#   inflating: negatives/negativePics/nosign10168.png
#   inflating: negatives/negativePics/nosign10169.png
#   inflating: negatives/negativePics/nosign10170.png
#   inflating: negatives/negativePics/nosign10171.png
#   inflating: negatives/negativePics/nosign10172.png
#   inflating: negatives/negativePics/nosign10173.png
#   inflating: negatives/negativePics/nosign10174.png
#   inflating: negatives/negativePics/nosign10175.png
#   inflating: negatives/negativePics/nosign10176.png
#   inflating: negatives/negativePics/nosign10177.png
#   inflating: negatives/negativePics/nosign10178.png
#   inflating: negatives/negativePics/nosign10179.png
#   inflating: negatives/negativePics/nosign10180.png
#   inflating: negatives/negativePics/nosign10181.png
#   inflating: negatives/negativePics/nosign10182.png
#   inflating: negatives/negativePics/nosign10183.png
#   inflating: negatives/negativePics/nosign10184.png
#   inflating: negatives/negativePics/nosign10185.png
#   inflating: negatives/negativePics/nosign10186.png
#   inflating: negatives/negativePics/nosign10187.png
#   inflating: negatives/negativePics/nosign10188.png
#   inflating: negatives/negativePics/nosign10189.png
#   inflating: negatives/negativePics/nosign10190.png
#   inflating: negatives/negativePics/nosign10191.png
#   inflating: negatives/negativePics/nosign10192.png
#   inflating: negatives/negativePics/nosign10193.png
#   inflating: negatives/negativePics/nosign10194.png
#   inflating: negatives/negativePics/nosign10195.png
#   inflating: negatives/negativePics/nosign10196.png
#   inflating: negatives/negativePics/nosign10197.png
#   inflating: negatives/negativePics/nosign10198.png
#   inflating: negatives/negativePics/nosign10199.png
#   inflating: negatives/negativePics/nosign10200.png
#   inflating: negatives/negativePics/nosign10201.png
#   inflating: negatives/negativePics/nosign10202.png
#   inflating: negatives/negativePics/nosign10203.png
#   inflating: negatives/negativePics/nosign10204.png
#   inflating: negatives/negativePics/nosign10205.png
#   inflating: negatives/negativePics/nosign10206.png
#   inflating: negatives/negativePics/nosign10207.png
#   inflating: negatives/negativePics/nosign10208.png
#   inflating: negatives/negativePics/nosign10209.png
#   inflating: negatives/negativePics/nosign10210.png
#   inflating: negatives/negativePics/nosign10211.png
#   inflating: negatives/negativePics/nosign10212.png
#   inflating: negatives/negativePics/nosign10213.png
#   inflating: negatives/negativePics/nosign10214.png
#   inflating: negatives/negativePics/nosign10215.png
#   inflating: negatives/negativePics/nosign10216.png
#   inflating: negatives/negativePics/nosign10217.png
#   inflating: negatives/negativePics/nosign10218.png
#   inflating: negatives/negativePics/nosign10219.png
#   inflating: negatives/negativePics/nosign10220.png
#   inflating: negatives/negativePics/nosign10221.png
#   inflating: negatives/negativePics/nosign10222.png
#   inflating: negatives/negativePics/nosign10223.png
#   inflating: negatives/negativePics/nosign10224.png
#   inflating: negatives/negativePics/nosign10225.png
#   inflating: negatives/negativePics/nosign10226.png
#   inflating: negatives/negativePics/nosign10227.png
#   inflating: negatives/negativePics/nosign10228.png
#   inflating: negatives/negativePics/nosign10229.png
#   inflating: negatives/negativePics/nosign10230.png
#   inflating: negatives/negativePics/nosign10231.png
#   inflating: negatives/negativePics/nosign10232.png
#   inflating: negatives/negativePics/nosign10233.png
#   inflating: negatives/negativePics/nosign10234.png
#   inflating: negatives/negativePics/nosign10235.png
#   inflating: negatives/negativePics/nosign10236.png
#   inflating: negatives/negativePics/nosign10237.png
#   inflating: negatives/negativePics/nosign10238.png
#   inflating: negatives/negativePics/nosign10239.png
#   inflating: negatives/negativePics/nosign10240.png
#   inflating: negatives/negativePics/nosign10241.png
#   inflating: negatives/negativePics/nosign10242.png
#   inflating: negatives/negativePics/nosign10243.png
#   inflating: negatives/negativePics/nosign10244.png
#   inflating: negatives/negativePics/nosign10245.png
#   inflating: negatives/negativePics/nosign10246.png
#   inflating: negatives/negativePics/nosign10247.png
#   inflating: negatives/negativePics/nosign10248.png
#   inflating: negatives/negativePics/nosign10249.png
#   inflating: negatives/negativePics/nosign10250.png
#   inflating: negatives/negativePics/nosign10251.png
#   inflating: negatives/negativePics/nosign10252.png
#   inflating: negatives/negativePics/nosign10253.png
#   inflating: negatives/negativePics/nosign10254.png
#   inflating: negatives/negativePics/nosign10255.png
#   inflating: negatives/negativePics/nosign10256.png
#   inflating: negatives/negativePics/nosign10257.png
#   inflating: negatives/negativePics/nosign10258.png
#   inflating: negatives/negativePics/nosign10259.png
#   inflating: negatives/negativePics/nosign10260.png
#   inflating: negatives/negativePics/nosign10261.png
#   inflating: negatives/negativePics/nosign10262.png
#   inflating: negatives/negativePics/nosign10263.png
#   inflating: negatives/negativePics/nosign10264.png
#   inflating: negatives/negativePics/nosign10265.png
#   inflating: negatives/negativePics/nosign10266.png
#   inflating: negatives/negativePics/nosign10267.png
#   inflating: negatives/negativePics/nosign10268.png
#   inflating: negatives/negativePics/nosign10269.png
#   inflating: negatives/negativePics/nosign10270.png
#   inflating: negatives/negativePics/nosign10271.png
#   inflating: negatives/negativePics/nosign10272.png
#   inflating: negatives/negativePics/nosign10273.png
#   inflating: negatives/negativePics/nosign10274.png
#   inflating: negatives/negativePics/nosign10275.png
#   inflating: negatives/negativePics/nosign10276.png
#   inflating: negatives/negativePics/nosign10277.png
#   inflating: negatives/negativePics/nosign10278.png
#   inflating: negatives/negativePics/nosign10279.png
#   inflating: negatives/negativePics/nosign10280.png
#   inflating: negatives/negativePics/nosign10281.png
#   inflating: negatives/negativePics/nosign10282.png
#   inflating: negatives/negativePics/nosign10283.png
#   inflating: negatives/negativePics/nosign10284.png
#   inflating: negatives/negativePics/nosign10285.png
#   inflating: negatives/negativePics/nosign10286.png
#   inflating: negatives/negativePics/nosign10287.png
#   inflating: negatives/negativePics/nosign10288.png
#   inflating: negatives/negativePics/nosign10289.png
#   inflating: negatives/negativePics/nosign10290.png
#   inflating: negatives/negativePics/nosign10291.png
#   inflating: negatives/negativePics/nosign10292.png
#   inflating: negatives/negativePics/nosign10293.png
#   inflating: negatives/negativePics/nosign10294.png
#   inflating: negatives/negativePics/nosign10295.png
#   inflating: negatives/negativePics/nosign10296.png
#   inflating: negatives/negativePics/nosign10297.png
#   inflating: negatives/negativePics/nosign10298.png
#   inflating: negatives/negativePics/nosign10299.png
#   inflating: negatives/negativePics/nosign10300.png
#   inflating: negatives/negativePics/nosign10301.png
#   inflating: negatives/negativePics/nosign10302.png
#   inflating: negatives/negativePics/nosign10303.png
#   inflating: negatives/negativePics/nosign10304.png
#   inflating: negatives/negativePics/nosign10305.png
#   inflating: negatives/negativePics/nosign10306.png
#   inflating: negatives/negativePics/nosign10307.png
#   inflating: negatives/negativePics/nosign10308.png
#   inflating: negatives/negativePics/nosign10309.png
#   inflating: negatives/negativePics/nosign10310.png
#   inflating: negatives/negativePics/nosign10311.png
#   inflating: negatives/negativePics/nosign10312.png
#   inflating: negatives/negativePics/nosign10313.png
#   inflating: negatives/negativePics/nosign10314.png
#   inflating: negatives/negativePics/nosign10315.png
#   inflating: negatives/negativePics/nosign10316.png
#   inflating: negatives/negativePics/nosign10317.png
#   inflating: negatives/negativePics/nosign10318.png
#   inflating: negatives/negativePics/nosign10319.png
#   inflating: negatives/negativePics/nosign10320.png
#   inflating: negatives/negativePics/nosign10321.png
#   inflating: negatives/negativePics/nosign10322.png
#   inflating: negatives/negativePics/nosign10323.png
#   inflating: negatives/negativePics/nosign10324.png
#   inflating: negatives/negativePics/nosign10325.png
#   inflating: negatives/negativePics/nosign10326.png
#   inflating: negatives/negativePics/nosign10327.png
#   inflating: negatives/negativePics/nosign10328.png
#   inflating: negatives/negativePics/nosign10329.png
#   inflating: negatives/negativePics/nosign10330.png
#   inflating: negatives/negativePics/nosign10331.png
#   inflating: negatives/negativePics/nosign10332.png
#   inflating: negatives/negativePics/nosign10333.png
#   inflating: negatives/negativePics/nosign10334.png
#   inflating: negatives/negativePics/nosign10335.png
#   inflating: negatives/negativePics/nosign10336.png
#   inflating: negatives/negativePics/nosign10337.png
#   inflating: negatives/negativePics/nosign10338.png
#   inflating: negatives/negativePics/nosign10339.png
#   inflating: negatives/negativePics/nosign10340.png
#   inflating: negatives/negativePics/nosign10341.png
#   inflating: negatives/negativePics/nosign10342.png
#   inflating: negatives/negativePics/nosign10343.png
#   inflating: negatives/negativePics/nosign10344.png
#   inflating: negatives/negativePics/nosign10345.png
#   inflating: negatives/negativePics/nosign10346.png
#   inflating: negatives/negativePics/nosign10347.png
#   inflating: negatives/negativePics/nosign10348.png
#   inflating: negatives/negativePics/nosign10349.png
#   inflating: negatives/negativePics/nosign10350.png
#   inflating: negatives/negativePics/nosign10351.png
#   inflating: negatives/negativePics/nosign10352.png
#   inflating: negatives/negativePics/nosign10353.png
#   inflating: negatives/negativePics/nosign10354.png
#   inflating: negatives/negativePics/nosign10355.png
#   inflating: negatives/negativePics/nosign10356.png
#   inflating: negatives/negativePics/nosign10357.png
#   inflating: negatives/negativePics/nosign10358.png
#   inflating: negatives/negativePics/nosign10359.png
#   inflating: negatives/negativePics/nosign10360.png
#   inflating: negatives/negativePics/nosign10361.png
#   inflating: negatives/negativePics/nosign10362.png
#   inflating: negatives/negativePics/nosign10363.png
#   inflating: negatives/negativePics/nosign10364.png
#   inflating: negatives/negativePics/nosign10365.png
#   inflating: negatives/negativePics/nosign10366.png
#   inflating: negatives/negativePics/nosign10367.png
#   inflating: negatives/negativePics/nosign10368.png
#   inflating: negatives/negativePics/nosign10369.png
#   inflating: negatives/negativePics/nosign10370.png
#   inflating: negatives/negativePics/nosign10371.png
#   inflating: negatives/negativePics/nosign10372.png
#   inflating: negatives/negativePics/nosign10373.png
#   inflating: negatives/negativePics/nosign10374.png
#   inflating: negatives/negativePics/nosign10375.png
#   inflating: negatives/negativePics/nosign10376.png
#   inflating: negatives/negativePics/nosign10377.png
#   inflating: negatives/negativePics/nosign10378.png
#   inflating: negatives/negativePics/nosign10379.png
#   inflating: negatives/negativePics/nosign10380.png
#   inflating: negatives/negativePics/nosign10381.png
#   inflating: negatives/negativePics/nosign10382.png
#   inflating: negatives/negativePics/nosign10383.png
#   inflating: negatives/negativePics/nosign10384.png
#   inflating: negatives/negativePics/nosign10385.png
#   inflating: negatives/negativePics/nosign10386.png
#   inflating: negatives/negativePics/nosign10387.png
#   inflating: negatives/negativePics/nosign10388.png
#   inflating: negatives/negativePics/nosign10389.png
#   inflating: negatives/negativePics/nosign10390.png
#   inflating: negatives/negativePics/nosign10391.png
#   inflating: negatives/negativePics/nosign10392.png
#   inflating: negatives/negativePics/nosign10393.png
#   inflating: negatives/negativePics/nosign10394.png
#   inflating: negatives/negativePics/nosign10395.png
#   inflating: negatives/negativePics/nosign10396.png
#   inflating: negatives/negativePics/nosign10397.png
#   inflating: negatives/negativePics/nosign10398.png
#   inflating: negatives/negativePics/nosign10399.png
#   inflating: negatives/negativePics/nosign10400.png
#   inflating: negatives/negativePics/nosign10401.png
# ...
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image7.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image8.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866175.avi_image9.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image0.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image1.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image2.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image7.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866196.avi_image8.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image0.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image1.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image2.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image7.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866354.avi_image8.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image0.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image1.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image2.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image7.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/speedLimit_1324866418.avi_image8.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image0.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image1.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image2.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stopAhead_1324866399.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image0.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image1.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image10.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image11.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image12.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image13.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image2.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image3.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image4.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image5.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image6.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image7.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image8.png
#   inflating: vid8/frameAnnotations-MVI_0120.MOV_annotations/stop_1324866406.avi_image9.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/Thumbs.db
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/frameAnnotations.csv
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/keepRight_1324866704.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/pedestrianCrossing_1324866507.avi_image8.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/signalAhead_1324866552.avi_image8.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866572.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866628.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866665.avi_image8.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866719.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866719.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866741.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866786.avi_image8.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866802.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866802.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866802.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866802.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866802.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866807.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866807.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866807.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/speedLimit_1324866807.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866463.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image0.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image1.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image10.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image11.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image12.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image13.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image14.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image15.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image16.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image17.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image18.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image19.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image2.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image20.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image21.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image22.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image23.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image24.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image25.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image26.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image27.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image3.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image4.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image5.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image6.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image7.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image8.png
#   inflating: vid9/frameAnnotations-MVI_0121.MOV_annotations/stop_1324866481.avi_image9.png
#   inflating: videoSources.txt

# %% [markdown]
# ## Setting up package versions
# Faster RCNN Inception Resnet V2 isn't available for Tensorflow 2 so you should downgrade to some version of tensorflow 1. I went with 1.15.0

# %%
! pip install tensorflow-gpu==1.15.0
! pip install numpy==1.21.6

# %% [markdown]
# ## Installing Object detection modules
# I would personally recommend installing models to your google drive. This is just more convenient

# %%
# you need to make branch is compatible with your version of tensorflow
! git clone -b r1.13.0 https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 72856, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 72856 (delta 14), reused 14 (delta 5), pack-reused 72825
# Receiving objects: 100% (72856/72856), 579.24 MiB | 30.91 MiB/s, done.
# Resolving deltas: 100% (51585/51585), done.

# %%
! cd models/research
! python setup.py build
! python setup.py install
! cd  slim
! python setup.py build
! python setup.py install

# %% [markdown]
# Install the pretrained model. We will be using this to initialize our weights

# %%
! wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.tar.gz
! tar -xvzf faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.tar.gz

# %% [markdown]
# ## Generate tf records

# %%
from PIL import Image
import tensorflow as tf
from object_detection.utils import dataset_util
import io
def get_data(name, df,ids):
    with tf.gfile.GFile(name, 'rb') as fid:
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    width, height = image.size

    filename = name.encode('utf8')
    image_format = b'png'
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []
    

    for index, row in df.iterrows():
        xmins.append(row["Upper left corner X"] / width)
        xmaxs.append(row["Lower right corner X"] / width)
        ymins.append(row["Upper left corner Y"] / height)
        ymaxs.append(row["Lower right corner Y"] / height)
        tmpc = ids[ids["Name"] == row["Annotation tag"]]["ID"].tolist()[0]
        classes_text.append(row["Annotation tag"].encode('utf8'))
        classes.append(tmpc+1)
    
    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv("allAnnotations.csv")
train, test = train_test_split(df, test_size=0.2)
train, val = train_test_split(df, test_size=0.25)

# %%
output_path = "lib/datasets/train.record"
groups = train.groupby("Filename")
writer = tf.python_io.TFRecordWriter(output_path)
ids = pd.read_csv("lib/datasets/ids.csv")
for name, group in groups:
    tf_example = get_data(name, group, ids)
    writer.write(tf_example.SerializeToString())
writer.close()

# %%
output_path = "lib/datasets/val.record"
groups = val.groupby("Filename")
writer = tf.python_io.TFRecordWriter(output_path)
ids = pd.read_csv("lib/datasets/ids.csv")
for name, group in groups:
    tf_example = get_data(name, group, ids)
    writer.write(tf_example.SerializeToString())
writer.close()

# %% [markdown]
# ## Set up config file
# The config file I used can be found in lib/faster_rcnn_inception_resnet_v2_atrous_coco.config
#
# You might want to adjust some of the paths depending on where you choose to store your files. These would be fine_tune_checkpoint under train_config and input_path and label_map_path under train_input_reader and eval_input_reader

# %%
class Config:
    def __init__(self):
        self.pipeline_config_path = "lib/faster_rcnn_inception_resnet_v2_atrous_coco.config"
        self.num_train_steps = None
        self.eval_on_train_data = False
        self.sample_1_of_n_eval_examples = 1
        self.sample_1_of_n_eval_on_train_examples = 5
        self.model_dir = "lib/models/model"
        self.checkpoint_dir = None
        self.eval_timeout = 3600
        self.use_tpu = False
        self.tpu_name = None
        self.num_workers = 1
        self.checkpoint_every_n = 1000
        self.record_summaries = True
        self.run_once = False
        self.max_eval_retries = 0
        self.task = 0
        self.master = ""
        self.num_clones = 1
        self.clone_on_cpu = False
        self.worker_replicas =1
        self.ps_tasks = 0
        self.train_dir = "lib/models/train"
        self.train_config_path = ""
        self.input_config_path = ""
        self.model_config_path = ""

# %% [markdown]
# ## Train the model

# %%
import functools
import json
import os
import tensorflow as tf

from object_detection.builders import dataset_builder
from object_detection.builders import graph_rewriter_builder
from object_detection.builders import model_builder
from object_detection.legacy import trainer
from object_detection.utils import config_util
def main(C):
    if C.task == 0:
        tf.gfile.MakeDirs(C.train_dir)
    if C.pipeline_config_path:
        configs = config_util.get_configs_from_pipeline_file(C.pipeline_config_path)
        if C.task == 0:
            tf.gfile.Copy(C.pipeline_config_path,os.path.join(C.train_dir, 'pipeline.config'),overwrite=True)
    else:
        configs = config_util.get_configs_from_multiple_files(
            model_config_path=C.model_config_path,
            train_config_path=C.train_config_path,
            train_input_config_path=C.input_config_path)
        if C.task == 0:
            for name, config in [('model.config', C.model_config_path),
                                ('train.config', C.train_config_path),
                                ('input.config', C.input_config_path)]:
                tf.gfile.Copy(config, os.path.join(C.train_dir, name),overwrite=True)
    model_config = configs['model']
    train_config = configs['train_config']
    input_config = configs['train_input_config']
    model_fn = functools.partial(
        model_builder.build,
        model_config=model_config,
        is_training=True)
    def get_next(config):
        return dataset_builder.make_initializable_iterator(dataset_builder.build(config)).get_next()
    create_input_dict_fn = functools.partial(get_next, input_config)

    env = json.loads(os.environ.get('TF_CONFIG', '{}'))
    cluster_data = env.get('cluster', None)
    cluster = tf.train.ClusterSpec(cluster_data) if cluster_data else None
    task_data = env.get('task', None) or {'type': 'master', 'index': 0}
    task_info = type('TaskSpec', (object,), task_data)
    # Parameters for a single worker.
    ps_tasks = 0
    worker_replicas = 1
    worker_job_name = 'lonely_worker'
    task = 0
    is_chief = True
    master = ''
    if cluster_data and 'worker' in cluster_data:
        # Number of total worker replicas include "worker"s and the "master".
        worker_replicas = len(cluster_data['worker']) + 1
    if cluster_data and 'ps' in cluster_data:
        ps_tasks = len(cluster_data['ps'])

    if worker_replicas > 1 and ps_tasks < 1:
        raise ValueError('At least 1 ps task is needed for distributed training.')

    if worker_replicas >= 1 and ps_tasks > 0:
        # Set up distributed training.
        server = tf.train.Server(tf.train.ClusterSpec(cluster), protocol='grpc',
                             job_name=task_info.type,
                             task_index=task_info.index)
        if task_info.type == 'ps':
            server.join()
            return

        worker_job_name = '%s/task:%d' % (task_info.type, task_info.index)
        task = task_info.index
        is_chief = (task_info.type == 'master')
        master = server.target

    graph_rewriter_fn = None
    if 'graph_rewriter_config' in configs:
        graph_rewriter_fn = graph_rewriter_builder.build(
            configs['graph_rewriter_config'], is_training=True)

    trainer.train(
        create_input_dict_fn,
        model_fn,
        train_config,
        master,
        task,
        C.num_clones,
        worker_replicas,
        C.clone_on_cpu,
        ps_tasks,
        worker_job_name,
        is_chief,
        C.train_dir,
        graph_hook_fn=graph_rewriter_fn)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
C = Config()
main(C)

# %% [markdown]
# ## Create inference Graph
# You want to make sure the XXXX in lib/models/train/model.ckpt-XXXX is the highest number checkpoint in lib/models/train

# %%
! python models/research/object_detection/export_inference_graph.py --input_type image_tensor --pipeline_config_path lib/faster_rcnn_inception_resnet_v2_atrous_coco.config --trained_checkpoint_prefix lib/models/train/model.ckpt-XXXX --output_directory lib/models/inference_graph
